# %% [markdown]
# <a href="https://colab.research.google.com/github/Pgupta1996/Bike_Sharing_Demand_Prediction/blob/main/Bike_Sharing_Demand_Prediction_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Seoul Bike Sharing Demand Prediction </u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b> The dataset contains weather information (Temperature, Humidity, Windspeed, Visibility, Dewpoint, Solar radiation, Snowfall, Rainfall), the number of bikes rented per hour and date information.</b>
#
#
# ### <b>Attribute Information: </b>
#
# * ### Date : year-month-day
# * ### Rented Bike count - Count of bikes rented at each hour
# * ### Hour - Hour of he day
# * ### Temperature-Temperature in Celsius
# * ### Humidity - %
# * ### Windspeed - m/s
# * ### Visibility - 10m
# * ### Dew point temperature - Celsius
# * ### Solar radiation - MJ/m2
# * ### Rainfall - mm
# * ### Snowfall - cm
# * ### Seasons - Winter, Spring, Summer, Autumn
# * ### Holiday - Holiday/No holiday
# * ### Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %%
#Importing important liabraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# Loading Data set and check their qualities

# %%
dataset = pd.read_csv("/content/SeoulBikeData.csv",encoding = 'unicode_escape')

# %%
dataset.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
dataset.tail()
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# ...

# %%
dataset.shape
# Out:
# (8760, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
# ...

# %%
dataset.isnull().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %%
dataset.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# ...

# %%
dataset.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
dataset['Seasons'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Autumn'], dtype=object)

# %%
# Since season, holiday and functioning are basically categorical values, converting them to string type for future use
dataset[['Seasons','Holiday','Functioning Day']] = dataset[['Seasons','Holiday','Functioning Day']].astype(str)

# %% [markdown]
# **DATA VISUALIZATION**

# %%
# Checking linear relationship between the rented bike count variable and other numeric variables
x =sns.pairplot(dataset, palette='husl', x_vars=['Temperature(°C)', 'Humidity(%)',
       'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
       'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)'], y_vars=['Rented Bike Count'], hue='Hour')
plt.legend(labels=['2017','2018'])
plt.show()

# %% [markdown]
# We can see that there is some corelation between all columns  and rented bike count with respect how much time they rented for bike. Also the count in 2017 are much higher than the count in 2018 for all circumstances.

# %%
# Checking the distribution of rented bike count across different categorical variables
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.boxplot(x='Seasons', y='Rented Bike Count', data=dataset, palette='husl')
plt.subplot(2,3,2)
sns.boxplot(x='Hour', y='Rented Bike Count', data=dataset, palette='husl')
plt.subplot(2,3,3)
sns.boxplot(x='Date', y='Rented Bike Count', data=dataset, palette='husl')
plt.subplot(2,3,4)
sns.boxplot(x='Holiday', y='Rented Bike Count', data=dataset, palette='husl')
plt.subplot(2,3,5)
sns.boxplot(x='Functioning Day', y='Rented Bike Count', data=dataset, palette='husl')
plt.show()

# %%
sns.boxplot(x='Seasons', y='Rented Bike Count', data=dataset, palette='husl')
plt.xlabel('Seasons')
plt.show()

# %%
sns.boxplot(x='Holiday', y='Rented Bike Count', data=dataset, palette='husl')
plt.xlabel('Holiday')
plt.show()

# %%
sns.boxplot(x='Functioning Day', y='Rented Bike Count', data=dataset, palette='husl')
plt.xlabel('Functioning Day')
plt.show()

# %%
# Since we have the month and the Year in two seperate columns, we do not need the date column anymore, thus dropping it
dataset.drop('Date', inplace=True, axis = 1)

# %%
# Moving the no. of rented bike to the end for easier identification
first_col = dataset.pop('Rented Bike Count')
dataset['Rented Bike Count'] = first_col

# %% [markdown]
# **Splitting the data into Train and Test Dataset**

# %%
dataset_train, dataset_test = train_test_split(dataset, train_size=0.7, random_state=100)

# %%
print('Shape of the Train data is:' , dataset_train.shape)
print('Shape of the Test data is:' , dataset_test.shape)
# Out:
# Shape of the Train data is: (6132, 13)
# Shape of the Test data is: (2628, 13)

# %%
# Checking the Train Data
pd.set_option('display.max_columns', None)
dataset_train.head()
# Out:
#       Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 5584    16             36.8           30               2.8              1756
# 5308     4             20.6           97               0.5              1989
# 5446    22             27.5           77               0.9              1778
# 7554    18             12.1           40               2.4              1854
# 3290     2              8.4           45               0.9              1987
#
#       Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# 5584                       16.3                     2.41           0.0
# 5308                       20.1                     0.00           0.0
# 5446                       23.0                     0.00           0.0
# 7554                       -1.1                     0.18           0.0
# 3290                       -2.8                     0.00           0.0
#
#       Snowfall (cm) Seasons     Holiday Functioning Day  Rented Bike Count
# ...

# %% [markdown]
# Other than the numeric fields, all other categorical values have been encoded. Now we can go ahead with the data.

# %%
# Checking the Heatmap
plt.figure(figsize=(24,15))
sns.heatmap(dataset_train.corr(),annot=True, cmap='YlGnBu')
plt.show()

# %% [markdown]
# From the above Heatmap we can clearly say that Rented bike count has strong colinearity with temp, humidity and dew point temp.
# But, temp and dew point temp have almost a perfect colinearity, so both cannot be part of the model. We keep this in mind while building the model in the following cells.

# %% [markdown]
# **Building the Model**

# %% [markdown]
# Since the number of columns is 13, which is manageable, we first build a model with all the columns, and then keep removing the columns based upon Statistical Significance and Co-Linearity.
# We will stop when we notice that there is no further improvement in the R2 value or all variables are statistically significant with low VIF(Variance Inflation Factor).

# %% [markdown]
# **There wil be several iterations before getting the perfect model, so please stay with me!!!**

# %%
y_train = dataset_train.pop('Rented Bike Count')
X_train = dataset_train
X_train_sm = sm.add_constant(X_train)
lr = sm.OLS(y_train, X_train_sm)
lr_model1 = lr.fit()
lr_model1.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-3d8713df0c99> in <module>()
#       2 X_train = dataset_train
#       3 X_train_sm = sm.add_constant(X_train)
# ----> 4 lr = sm.OLS(y_train, X_train_sm)
#       5 lr_model1 = lr.fit()
#       6 lr_model1.summary()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...
